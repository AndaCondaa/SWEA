# %%
#1~9 사이의 정수 a를 입력받아 a + aa + aaa + aaaa 의 값을 계산하는 프로그램을 작성하십시오.

# %%
def output(a):
    result = a + (a+a*10) + (a+a*10+a*100) + (a+a*10+a*100+a*1000)
    return print("결과값은 {결과} 입니다.".format(결과=result))

a = int(input("1~9 사이의 정수 a를 입력하세요: " ))

output(a)
# Out:
# 1~9 사이의 정수 a를 입력하세요: 1
# 결과값은 1234 입니다.
